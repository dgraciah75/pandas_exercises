# %% [markdown]
# # Fictional Army - Filtering and Sorting

# %% [markdown]
# ### Introduction:
#
# This exercise was inspired by this [page](http://chrisalbon.com/python/)
#
# Special thanks to: https://github.com/chrisalbon for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. This is the data given as a dictionary

# %%
# Create an example dataframe about a fictional army
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %% [markdown]
# ### Step 3. Create a dataframe and assign it to a variable called army.
#
# #### Don't forget to include the columns names in the order presented in the dictionary ('regiment', 'company', 'deaths'...) so that the column index order is consistent with the solutions. If omitted, pandas will order the columns alphabetically.

# %%
pd.DataFrame(raw_data)
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 1   Nighthawks     1st      52       42   957         5          2        0
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 5     Dragoons     1st     234        7  1006        37          1        1
# 6     Dragoons     2nd     523        8   987       949          2        0
# 7     Dragoons     2nd      62        3   849        48          3        1
# 8       Scouts     1st      62        4   973        48          2        0
# 9       Scouts     1st      73        7  1005       435          1        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# ...

# %%
df_army=pd.DataFrame(raw_data)

# %%
df_army
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 1   Nighthawks     1st      52       42   957         5          2        0
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 5     Dragoons     1st     234        7  1006        37          1        1
# 6     Dragoons     2nd     523        8   987       949          2        0
# 7     Dragoons     2nd      62        3   849        48          3        1
# 8       Scouts     1st      62        4   973        48          2        0
# 9       Scouts     1st      73        7  1005       435          1        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# ...

# %% [markdown]
# ### Step 4. Set the 'origin' colum as the index of the dataframe

# %%
df_army=df_army.set_index('origin')

# %%
df_army
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %% [markdown]
# ### Step 5. Print only the column veterans

# %%
df_army.veterans
# Out:
# origin
# Arizona         1
# California      5
# Texas          62
# Florida        26
# Maine          73
# Iowa           37
# Alaska        949
# Washington     48
# Oregon         48
# Wyoming       435
# Louisana       63
# Georgia       345
# Name: veterans, dtype: int64

# %% [markdown]
# ### Step 6. Print the columns 'veterans' and 'deaths'

# %%
df_army['veterans','deaths']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('veterans', 'deaths')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# Da error de clave porque interpreta un string.Tendríamos que darle como atributo una lista por lo que ponemos un corchete

# %%
df_army[['veterans','deaths']]
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washington        48      62
# Oregon            48      62
# Wyoming          435      73
# Louisana          63      37
# Georgia          345      35

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
df_army.keys()
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters'],
#       dtype='object')

# %%
# opcion de internet
list(df_army.columns)
# Out:
# ['regiment',
#  'company',
#  'deaths',
#  'battles',
#  'size',
#  'veterans',
#  'readiness',
#  'armored',
#  'deserters']

# %% [markdown]
# ### Step 8. Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska

# %%
df_army[['deaths','size','deserters']]
# Out:
#             deaths  size  deserters
# origin
# Arizona        523  1045          4
# California      52   957         24
# Texas           25  1099         31
# Florida        616  1400          2
# Maine           43  1592          3
# Iowa           234  1006          4
# Alaska         523   987         24
# Washington      62   849         31
# Oregon          62   973          2
# Wyoming         73  1005          3
# Louisana        37  1099          2
# Georgia         35  1523          3

# %%
mask_alaska=df_army.origin=='Alaska'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [104], in <cell line: 1>()
# ----> 1 mask_alaska=df_army.origin=='Alaska'
#
# File ~\miniconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'origin'

# %%
mask_maine=df_army.origin=='Maine'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [105], in <cell line: 1>()
# ----> 1 mask_maine=df_army.origin=='Maine'
#
# File ~\miniconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'origin'

# %%
df_army[mask_alaska | mask_maine]
# Out:
# C:\Users\nettr\AppData\Local\Temp\ipykernel_6652\1107935570.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_army[mask_alaska | mask_maine]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Input In [106], in <cell line: 1>()
# ----> 1 df_army[mask_alaska | mask_maine]
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:3496, in DataFrame.__getitem__(self, key)
#    3494 # Do we have a (boolean) 1d indexer?
#    3495 if com.is_bool_indexer(key):
# -> 3496     return self._getitem_bool_array(key)
#    3498 # We are left with two options: a single key, and a collection of keys,
#    3499 # We interpret tuples as collections only for non-MultiIndex
#    3500 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:3549, in DataFrame._getitem_bool_array(self, key)
# ...

# %%
df_army.query('origin =="Alaska" | origin=="Maine"')
# Out:
#         regiment company  deaths  battles  size  veterans  readiness  armored  \
# origin
# Maine   Dragoons     1st      43        4  1592        73          2        0
# Alaska  Dragoons     2nd     523        8   987       949          2        0
#
#         deserters
# origin
# Maine           3
# Alaska         24

# %%
estados=df_army.query('origin =="Alaska" | origin=="Maine"')

# %%
df_army.query('origin =="Alaska" | origin=="Maine"')[['deaths','size','deserters']]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %%
estados[['deaths','size','deserters']]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %%
df_army[mask_alaska | mask_maine][['deaths','size','deserters']]
# Out:
# C:\Users\nettr\AppData\Local\Temp\ipykernel_6652\1718786530.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_army[mask_alaska | mask_maine][['deaths','size','deserters']]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Input In [111], in <cell line: 1>()
# ----> 1 df_army[mask_alaska | mask_maine][['deaths','size','deserters']]
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:3496, in DataFrame.__getitem__(self, key)
#    3494 # Do we have a (boolean) 1d indexer?
#    3495 if com.is_bool_indexer(key):
# -> 3496     return self._getitem_bool_array(key)
#    3498 # We are left with two options: a single key, and a collection of keys,
#    3499 # We interpret tuples as collections only for non-MultiIndex
#    3500 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# ...

# %% [markdown]
# ### Step 9. Select the rows 3 to 7 and the columns 3 to 6

# %%
df_army.iloc[2:7,2:6]
# Out:
#          deaths  battles  size  veterans
# origin
# Texas        25        2  1099        62
# Florida     616        2  1400        26
# Maine        43        4  1592        73
# Iowa        234        7  1006        37
# Alaska      523        8   987       949

# %% [markdown]
# ### Step 10. Select every row after the fourth row and all columns

# %%
df_army.loc[3:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [113], in <cell line: 1>()
# ----> 1 df_army.loc[3:]
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:1180, in _LocIndexer._getitem_axis(self, key, axis)
#    1178 if isinstance(key, slice):
#    1179     self._validate_key(key, axis)
# -> 1180     return self._get_slice_axis(key, axis=axis)
#    1181 elif com.is_bool_indexer(key):
#    1182     return self._getbool_axis(key, axis=axis)
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:1214, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
# ...

# %% [markdown]
# ### Step 11. Select every row up to the 4th row and all columns

# %%
df_army.loc[:3]
# Out:
#      regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0  Nighthawks     1st     523        5  1045         1          1        1
# 1  Nighthawks     1st      52       42   957         5          2        0
# 2  Nighthawks     2nd      25        2  1099        62          3        1
# 3  Nighthawks     2nd     616        2  1400        26          3        1
#
#    deserters      origin
# 0          4     Arizona
# 1         24  California
# 2         31       Texas
# 3          2     Florida

# %% [markdown]
# ### Step 12. Select the 3rd column up to the 7th column

# %%
df_army[df_army.columns[2:7]]
# Out:
#     deaths  battles  size  veterans  readiness
# 0      523        5  1045         1          1
# 1       52       42   957         5          2
# 2       25        2  1099        62          3
# 3      616        2  1400        26          3
# 4       43        4  1592        73          2
# 5      234        7  1006        37          1
# 6      523        8   987       949          2
# 7       62        3   849        48          3
# 8       62        4   973        48          2
# 9       73        7  1005       435          1
# 10      37        8  1099        63          2
# 11      35        9  1523       345          3

# %%
df_army.iloc[:,2:7]
# Out:
#     deaths  battles  size  veterans  readiness
# 0      523        5  1045         1          1
# 1       52       42   957         5          2
# 2       25        2  1099        62          3
# 3      616        2  1400        26          3
# 4       43        4  1592        73          2
# 5      234        7  1006        37          1
# 6      523        8   987       949          2
# 7       62        3   849        48          3
# 8       62        4   973        48          2
# 9       73        7  1005       435          1
# 10      37        8  1099        63          2
# 11      35        9  1523       345          3

# %% [markdown]
# ### Step 13. Select rows where df.deaths is greater than 50

# %%
df_army.query('deaths > 50')
# Out:
#      regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0  Nighthawks     1st     523        5  1045         1          1        1
# 1  Nighthawks     1st      52       42   957         5          2        0
# 3  Nighthawks     2nd     616        2  1400        26          3        1
# 5    Dragoons     1st     234        7  1006        37          1        1
# 6    Dragoons     2nd     523        8   987       949          2        0
# 7    Dragoons     2nd      62        3   849        48          3        1
# 8      Scouts     1st      62        4   973        48          2        0
# 9      Scouts     1st      73        7  1005       435          1        0
#
#    deserters      origin
# 0          4     Arizona
# 1         24  California
# 3          2     Florida
# 5          4        Iowa
# 6         24      Alaska
# 7         31  Washington
# 8          2      Oregon
# 9          3     Wyoming

# %% [markdown]
# ### Step 14. Select rows where df.deaths is greater than 500 or less than 50

# %%
df_army.query('deaths >500 | deaths < 50')
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 6     Dragoons     2nd     523        8   987       949          2        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# 11      Scouts     2nd      35        9  1523       345          3        1
#
#     deserters    origin
# 0           4   Arizona
# 2          31     Texas
# 3           2   Florida
# 4           3     Maine
# 6          24    Alaska
# 10          2  Louisana
# 11          3   Georgia

# %% [markdown]
# ### Step 15. Select all the regiments not named "Dragoons"

# %%
df_army.query('regiment != "Dragoons"')
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 1   Nighthawks     1st      52       42   957         5          2        0
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 8       Scouts     1st      62        4   973        48          2        0
# 9       Scouts     1st      73        7  1005       435          1        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# 11      Scouts     2nd      35        9  1523       345          3        1
#
#     deserters      origin
# 0           4     Arizona
# 1          24  California
# 2          31       Texas
# 3           2     Florida
# 8           2      Oregon
# 9           3     Wyoming
# 10          2    Louisana
# 11          3     Georgia

# %%
noDragon=df_army.regiment != 'Dragoons'

# %%
df_army[noDragon].regiment
# Out:
# 0     Nighthawks
# 1     Nighthawks
# 2     Nighthawks
# 3     Nighthawks
# 8         Scouts
# 9         Scouts
# 10        Scouts
# 11        Scouts
# Name: regiment, dtype: object

# %% [markdown]
# ### Step 16. Select the rows called Texas and Arizona

# %%
df_army.query('origin=="Arizona" | origin=="Texas"')
# Out:
#      regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0  Nighthawks     1st     523        5  1045         1          1        1
# 2  Nighthawks     2nd      25        2  1099        62          3        1
#
#    deserters   origin
# 0          4  Arizona
# 2         31    Texas

# %% [markdown]
# ### Step 17. Select the third cell in the row named Arizona

# %% [markdown]
# ### Step 18. Select the third cell down in the column named deaths
